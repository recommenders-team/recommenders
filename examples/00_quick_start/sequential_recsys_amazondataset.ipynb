# %% [markdown]
# <i>Copyright (c) Microsoft Corporation. All rights reserved.</i>
#
# <i>Licensed under the MIT License.</i>

# %% [markdown]
# # Sequential Recommender Quick Start
#
# ### Example: SLi_Rec : Adaptive User Modeling with Long and Short-Term Preferences for Personailzed Recommendation
# Unlike a general recommender such as Matrix Factorization or xDeepFM (in the repo) which doesn't consider the order of the user's activities, sequential recommender systems take the sequence of the user behaviors as context and the goal is to predict the items that the user will interact in a short time (in an extreme case, the item that the user will interact next).
#
# This notebook aims to give you a quick example of how to train a sequential model based on a public Amazon dataset. Currently, we can support NextItNet \[4\], GRU4Rec \[2\], Caser \[3\], A2SVD \[1\] and SLi_Rec \[1\]. Without loss of generality, this notebook takes [SLi_Rec model](https://www.microsoft.com/en-us/research/uploads/prod/2019/07/IJCAI19-ready_v1.pdf) for example.
# SLi_Rec \[1\] is a deep learning-based model aims at capturing both long and short-term user preferences for precise recommender systems. To summarize, SLi_Rec has the following key properties:
#
# * It adopts the attentive "Asymmetric-SVD" paradigm for long-term modeling;
# * It takes both time irregularity and semantic irregularity into consideration by modifying the gating logic in LSTM.
# * It uses an attention mechanism to dynamic fuse the long-term component and short-term component.
#
# In this notebook, we test SLi_Rec on a subset of the public dataset: [Amazon_reviews](http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/reviews_Movies_and_TV_5.json.gz) and [Amazon_metadata](http://snap.stanford.edu/data/amazon/productGraph/categoryFiles/meta_Movies_and_TV.json.gz)

# %% [markdown]
# ## 0. Global Settings and Imports

# %%
import sys
sys.path.append("../../")
import os
import logging
import papermill as pm
from tempfile import TemporaryDirectory

import tensorflow as tf
import time

import numpy as np

from reco_utils.common.constants import SEED
from reco_utils.recommender.deeprec.deeprec_utils import (
    prepare_hparams
)
from reco_utils.dataset.amazon_reviews import download_and_extract, data_preprocessing
from reco_utils.dataset.download_utils import maybe_download


from reco_utils.recommender.deeprec.models.sequential.sli_rec import SLI_RECModel as SeqModel
####  to use the other model, use one of the following lines:
# from reco_utils.recommender.deeprec.models.sequential.asvd import A2SVDModel as SeqModel
# from reco_utils.recommender.deeprec.models.sequential.caser import CaserModel as SeqModel
# from reco_utils.recommender.deeprec.models.sequential.gru4rec import GRU4RecModel as SeqModel

#from reco_utils.recommender.deeprec.models.sequential.nextitnet import NextItNetModel

from reco_utils.recommender.deeprec.io.sequential_iterator import SequentialIterator
#from reco_utils.recommender.deeprec.io.nextitnet_iterator import NextItNetIterator



##  ATTENTION: change to the corresponding config file, e.g., caser.yaml for CaserModel 
yaml_file = '../../reco_utils/recommender/deeprec/config/sli_rec.yaml'

# %%
print("System version: {}".format(sys.version))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# System version: 3.6.8 |Anaconda, Inc.| (default, Dec 30 2018, 01:22:34)
# [GCC 7.3.0]
# Tensorflow version: 1.15.0

# %% [markdown]
# #### Parameters

# %%
EPOCHS = 10
BATCH_SIZE = 400
RANDOM_SEED = SEED  # Set None for non-deterministic result

data_path = os.path.join("..", "..", "tests", "resources", "deeprec", "slirec")

# %% [markdown]
# ##  1. Input data format
# The input data contains 8 columns, i.e.,   `<label> <user_id> <item_id> <category_id> <timestamp> <history_item_ids> <history_cateory_ids> <hitory_timestamp>`  columns are seperated by `"\t"`.  item_id and category_id denote the target item and category, which means that for this instance, we want to guess whether user user_id will interact with item_id at timestamp. `<history_*>` columns record the user behavior list up to `<timestamp>`, elements are separated by commas.  `<label>` is a binary value with 1 for positive instances and 0 for negative instances.  One example for an instance is:
#
# `1       A1QQ86H5M2LVW2  B0059XTU1S      Movies  1377561600      B002ZG97WE,B004IK30PA,B000BNX3AU,B0017ANB08,B005LAIHW2  Movies,Movies,Movies,Movies,Movies   1304294400,1304812800,1315785600,1316304000,1356998400`
#
# Only the SLi_Rec model is time-aware. For the other models, you can just pad some meaningless timestamp in the data files to fill up the format, the models will ignore these columns.
#
# We use Softmax to the loss function. In training and evalution stage, we group 1 positive instance with num_ngs negative instances. Pair-wise ranking can be regarded as a special case of Softmax ranking, where num_ngs is set to 1.
#
# More specifically,  for training and evalation, you need to organize the data file such that each one positive instance is followd by num_ngs negative instances. Our program will take 1+num_ngs lines as a unit for Softmax calculation. num_ngs is a parameter you need to pass to the `prepare_hparams`, `fit` and `run_eval` function. `train_num_ngs` in `prepare_hparams` denotes the number of negative instances for training, where a recommended number is 4. `valid_num_ngs` and `num_ngs` in `fit` and `run_eval` denote the number in evalution. In evaluation, the model calculates metrics among the 1+num_ngs instances. For the `predict` function, since we only need to calcuate a socre for each individual instance, there is no need for num_ngs setting.  More details and examples will be provided in the following sections.
#
# For training stage, if you don't want to prepare negative instances, you can just provide positive instances and set the parameter `need_sample=True, train_num_ngs=train_num_ngs` for function `prepare_hparams`, our model will dynamicly sample `train_num_ngs` instances as negative samples in each mini batch.
#
# ###  Amazon dataset
# Now let's start with a public dataset containing product reviews and metadata from Amazon, which is widely used as a benchmark dataset in recommemdation systems field.

# %%
# for test
train_file = os.path.join(data_path, r'train_data')
valid_file = os.path.join(data_path, r'valid_data')
test_file = os.path.join(data_path, r'test_data')
user_vocab = os.path.join(data_path, r'user_vocab.pkl')
item_vocab = os.path.join(data_path, r'item_vocab.pkl')
cate_vocab = os.path.join(data_path, r'category_vocab.pkl')
output_file = os.path.join(data_path, r'output.txt')

reviews_name = 'reviews_Movies_and_TV_5.json'
meta_name = 'meta_Movies_and_TV.json'
reviews_file = os.path.join(data_path, reviews_name)
meta_file = os.path.join(data_path, meta_name)
train_num_ngs = 4 # number of negative instances with a positive instance for training
valid_num_ngs = 4 # number of negative instances with a positive instance for validation
test_num_ngs = 9 # number of negative instances with a positive instance for testing
sample_rate = 0.01 # sample a small item set for training and testing here for fast example

input_files = [reviews_file, meta_file, train_file, valid_file, test_file, user_vocab, item_vocab, cate_vocab]

if not os.path.exists(train_file):
    download_and_extract(reviews_name, reviews_file)
    download_and_extract(meta_name, meta_file)
    data_preprocessing(*input_files, sample_rate=sample_rate, valid_num_ngs=valid_num_ngs, test_num_ngs=test_num_ngs)
    #### uncomment this for the NextItNet model, because it does not need to unfold the user history
    # data_preprocessing(*input_files, sample_rate=sample_rate, valid_num_ngs=valid_num_ngs, test_num_ngs=test_num_ngs, is_history_expanding=False)

# %% [markdown]
# #### 1.1 Prepare hyper-parameters
# prepare_hparams() will create a full set of hyper-parameters for model training, such as learning rate, feature number, and dropout ratio. We can put those parameters in a yaml file (a complete list of parameters can be found under our config folder) , or pass parameters as the function's parameters (which will overwrite yaml settings).
#
# Parameters hints: <br>
# `need_sample` controls whether to perform dynamic negative sampling in mini-batch.
# `train_num_ngs` indicates how many negative instances followed by one positive instances.  <br>
# Examples: <br>
# (1) `need_sample=True and train_num_ngs=4`:  There are only positive instances in your training file. Our model will dynamically sample 4 negative instances for each positive instances in mini-batch. Note that if need_sample is set to True, train_num_ngs should be greater than zero. <br>
# (2) `need_sample=False and train_num_ngs=4`: In your training file, each one positive line is followed by 4 negative lines. Note that if need_sample is set to False, you must provide a traiing file with negative instances, and train_num_ngs should match the number of negative number in your training file.

# %%
hparams = prepare_hparams(yaml_file, 
                          embed_l2=0., 
                          layer_l2=0., 
                          learning_rate=0.001,  # set to 0.01 if batch normalization is disable
                          epochs=EPOCHS,
                          batch_size=BATCH_SIZE,
                          show_step=20,
                          MODEL_DIR=os.path.join(data_path, "model/"),
                          SUMMARIES_DIR=os.path.join(data_path, "summary/"),
                          user_vocab=user_vocab,
                          item_vocab=item_vocab,
                          cate_vocab=cate_vocab,
                          need_sample=True,
                          train_num_ngs=train_num_ngs, # provides the number of negative instances for each positive instance for loss computation.
            )
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# #### 1.2 Create data loader
# Designate a data iterator for the model. All our sequential models use SequentialIterator.
# data format is introduced aboved.
#
# <br>Validation and testing data are files after negative sampling offline with the number of `<num_ngs>` and `<test_num_ngs>`.

# %%
input_creator = SequentialIterator
#### uncomment this for the NextItNet model, because it needs a special data iterator for training
#input_creator = NextItNetIterator

# %% [markdown]
# ## 2. Create model
# When both hyper-parameters and data iterator are ready, we can create a model:

# %%
model = SeqModel(hparams, input_creator, seed=RANDOM_SEED)

## sometimes we don't want to train a model from scratch
## then we can load a pre-trained model like this: 
#model.load_model(r'your_model_path')
# Out:
# WARNING:tensorflow:From ../../reco_utils/recommender/deeprec/models/sequential/sequential_base_model.py:43: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From ../../reco_utils/recommender/deeprec/models/sequential/sequential_base_model.py:64: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From ../../reco_utils/recommender/deeprec/models/sequential/sequential_base_model.py:253: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From ../../reco_utils/recommender/deeprec/models/sequential/sequential_base_model.py:275: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From ../../reco_utils/recommender/deeprec/models/sequential/sli_rec.py:64: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From ../../reco_utils/recommender/deeprec/models/sequential/rnn_cell_implement.py:621: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/v-xdeng/.conda/envs/reco_tf15/lib/python3.6/site-packages/tensorflow_core/python/ops/rnn.py:244: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From ../../reco_utils/recommender/deeprec/models/base_model.py:677: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From /home/v-xdeng/.conda/envs/reco_tf15/lib/python3.6/site-packages/tensorflow_core/python/layers/normalization.py:327: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From ../../reco_utils/recommender/deeprec/models/base_model.py:340: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From ../../reco_utils/recommender/deeprec/models/sequential/sequential_base_model.py:332: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.

# %% [markdown]
# Now let's see what is the model's performance at this point (without starting training):

# %%
print(model.run_eval(test_file, num_ngs=test_num_ngs)) # test_num_ngs is the number of negative lines after each positive line in your test_file
# Out:
# {'auc': 0.5137, 'logloss': 0.6931, 'mean_mrr': 0.2893, 'ndcg@2': 0.161, 'ndcg@4': 0.248, 'ndcg@6': 0.3228, 'group_auc': 0.514}

# %% [markdown]
# AUC=0.5 is a state of random guess. We can see that before training, the model behaves like random guessing.
#
# #### 2.1 Train model
# Next we want to train the model on a training set, and check the performance on a validation dataset. Training the model is as simple as a function call:

# %%
start_time = time.time()
model = model.fit(train_file, valid_file, valid_num_ngs=valid_num_ngs) 
# valid_num_ngs is the number of negative lines after each positive line in your valid_file 
# we will evaluate the performance of model on valid_file every epoch
end_time = time.time()
print('Time cost for training is {0:.2f} mins'.format((end_time-start_time)/60.0))
# Out:
# WARNING:tensorflow:From ../../reco_utils/recommender/deeprec/models/sequential/sequential_base_model.py:105: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# step 20 , total_loss: 1.6122, data_loss: 1.6122
# eval valid at epoch 1: auc:0.5088,logloss:0.6931,mean_mrr:0.4623,ndcg@2:0.3321,ndcg@4:0.5188,ndcg@6:0.594,group_auc:0.5071
# step 20 , total_loss: 1.5740, data_loss: 1.5740
# eval valid at epoch 2: auc:0.5709,logloss:0.6965,mean_mrr:0.5217,ndcg@2:0.4216,ndcg@4:0.5878,ndcg@6:0.6399,group_auc:0.5876
# step 20 , total_loss: 1.4441, data_loss: 1.4441
# eval valid at epoch 3: auc:0.6733,logloss:0.8291,mean_mrr:0.5962,ndcg@2:0.524,ndcg@4:0.6598,ndcg@6:0.6965,group_auc:0.6672
# step 20 , total_loss: 1.3054, data_loss: 1.3054
# eval valid at epoch 4: auc:0.7021,logloss:0.7882,mean_mrr:0.6362,ndcg@2:0.5794,ndcg@4:0.6974,ndcg@6:0.7269,group_auc:0.7085
# step 20 , total_loss: 1.3181, data_loss: 1.3181
# eval valid at epoch 5: auc:0.7119,logloss:0.6315,mean_mrr:0.6302,ndcg@2:0.5733,ndcg@4:0.6956,ndcg@6:0.7227,group_auc:0.71
# step 20 , total_loss: 1.1659, data_loss: 1.1659
# eval valid at epoch 6: auc:0.7277,logloss:0.6974,mean_mrr:0.6609,ndcg@2:0.6056,ndcg@4:0.7205,ndcg@6:0.7456,group_auc:0.7319
# step 20 , total_loss: 1.1980, data_loss: 1.1980
# eval valid at epoch 7: auc:0.7331,logloss:0.6623,mean_mrr:0.6615,ndcg@2:0.609,ndcg@4:0.7221,ndcg@6:0.7462,group_auc:0.7349
# step 20 , total_loss: 1.2404, data_loss: 1.2404
# eval valid at epoch 8: auc:0.7363,logloss:0.68,mean_mrr:0.6687,ndcg@2:0.6178,ndcg@4:0.7274,ndcg@6:0.7516,group_auc:0.7401
# step 20 , total_loss: 1.1585, data_loss: 1.1585
# eval valid at epoch 9: auc:0.7442,logloss:0.6297,mean_mrr:0.6706,ndcg@2:0.6201,ndcg@4:0.7275,ndcg@6:0.7529,group_auc:0.7396
# step 20 , total_loss: 1.0657, data_loss: 1.0657
# eval valid at epoch 10: auc:0.7402,logloss:0.6048,mean_mrr:0.6683,ndcg@2:0.6153,ndcg@4:0.7289,ndcg@6:0.7512,group_auc:0.7406
# [(1, {'auc': 0.5088, 'logloss': 0.6931, 'mean_mrr': 0.4623, 'ndcg@2': 0.3321, 'ndcg@4': 0.5188, 'ndcg@6': 0.594, 'group_auc': 0.5071}), (2, {'auc': 0.5709, 'logloss': 0.6965, 'mean_mrr': 0.5217, 'ndcg@2': 0.4216, 'ndcg@4': 0.5878, 'ndcg@6': 0.6399, 'group_auc': 0.5876}), (3, {'auc': 0.6733, 'logloss': 0.8291, 'mean_mrr': 0.5962, 'ndcg@2': 0.524, 'ndcg@4': 0.6598, 'ndcg@6': 0.6965, 'group_auc': 0.6672}), (4, {'auc': 0.7021, 'logloss': 0.7882, 'mean_mrr': 0.6362, 'ndcg@2': 0.5794, 'ndcg@4': 0.6974, 'ndcg@6': 0.7269, 'group_auc': 0.7085}), (5, {'auc': 0.7119, 'logloss': 0.6315, 'mean_mrr': 0.6302, 'ndcg@2': 0.5733, 'ndcg@4': 0.6956, 'ndcg@6': 0.7227, 'group_auc': 0.71}), (6, {'auc': 0.7277, 'logloss': 0.6974, 'mean_mrr': 0.6609, 'ndcg@2': 0.6056, 'ndcg@4': 0.7205, 'ndcg@6': 0.7456, 'group_auc': 0.7319}), (7, {'auc': 0.7331, 'logloss': 0.6623, 'mean_mrr': 0.6615, 'ndcg@2': 0.609, 'ndcg@4': 0.7221, 'ndcg@6': 0.7462, 'group_auc': 0.7349}), (8, {'auc': 0.7363, 'logloss': 0.68, 'mean_mrr': 0.6687, 'ndcg@2': 0.6178, 'ndcg@4': 0.7274, 'ndcg@6': 0.7516, 'group_auc': 0.7401}), (9, {'auc': 0.7442, 'logloss': 0.6297, 'mean_mrr': 0.6706, 'ndcg@2': 0.6201, 'ndcg@4': 0.7275, 'ndcg@6': 0.7529, 'group_auc': 0.7396}), (10, {'auc': 0.7402, 'logloss': 0.6048, 'mean_mrr': 0.6683, 'ndcg@2': 0.6153, 'ndcg@4': 0.7289, 'ndcg@6': 0.7512, 'group_auc': 0.7406})]
# best epoch: 10
# Time cost for training is 2.68 mins

# %% [markdown]
# #### 2.2  Evaluate model
#
# Again, let's see what is the model's performance now (after training):

# %%
res_syn = model.run_eval(test_file, num_ngs=test_num_ngs)
print(res_syn)
pm.record("res_syn", res_syn)
# Out:
# {'auc': 0.7099, 'logloss': 0.6063, 'mean_mrr': 0.4902, 'ndcg@2': 0.4025, 'ndcg@4': 0.5056, 'ndcg@6': 0.5555, 'group_auc': 0.709}
# /home/v-xdeng/.conda/envs/reco_tf15/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Function record is deprecated and will be removed in verison 1.0.0 (current version 0.19.1). Please see `scrapbook.glue` (nteract-scrapbook) as a replacement for this functionality.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# If we want to get the full prediction scores rather than evaluation metrics, we can do this:

# %%
model = model.predict(test_file, output_file)
# Out:
# WARNING:tensorflow:From ../../reco_utils/recommender/deeprec/models/sequential/sequential_base_model.py:231: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.

# %%
# The data was downloaded in tmpdir folder. You can delete them manually if you do not need them any more.

# %% [markdown]
# #### 2.3  Running models with large dataset
# Here are performances using the whole amazon dataset among popular sequential models with 1,697,533 positive instances.
# <br>Settings for reproducing the results:
# <br>`learning_rate=0.001, dropout=0.3, item_embedding_dim=32, cate_embedding_dim=8, l2_norm=0, batch_size=400,
# train_num_ngs=4, valid_num_ngs=4, test_num_ngs=49`
#
#
# We compare the running time with CPU only and with GPU on the larger dataset. It appears that GPU can significantly accelerate the training. Hardware specification for running the large dataset:
# <br>GPU: Tesla P100-PCIE-16GB
# <br>CPU: 6 cores Intel(R) Xeon(R) CPU E5-2690 v4 @ 2.60GHz
#
# | Models | AUC | g-AUC | NDCG@2 | NDCG@10 | seconds per epoch on GPU | seconds per epoch on CPU| config |
# | :------| :------: | :------: | :------: | :------: | :------: | :------: | :------ |
# | A2SVD | 0.8251 | 0.8178 | 0.2922 | 0.4264 | 249.5 | 440.0 | N/A |
# | GRU4Rec | 0.8411 | 0.8332 | 0.3213 | 0.4547 | 439.0 | 4285.0 | max_seq_length=50, hidden_size=40|
# | Caser | 0.8244 | 0.8171 | 0.283 | 0.4194 | 314.3 | 5369.9 | T=1, n_v=128, n_h=128, L=3, min_seq_length=5|
# | SLi_Rec | 0.8631 | 0.8519 | 0.3491 | 0.4842 | 549.6 | 5014.0 | attention_size=40, max_seq_length=50, hidden_size=40|
# | NextItNet* | 0.6793 | 0.6769 | 0.0602 | 0.1733 | 112.0 | 214.5 | min_seq_length=3, dilations=\[1,2,4,1,2,4\], kernel_size=3 |
#
#  Note 1: The five models are grid searched with a coarse granularity and the results are for reference only.
#  <br>Note 2: NextItNet model requires a dataset with strong sequence property, but the Amazon dataset used in this notebook does not meet that requirement, so NextItNet Model may not performance good. If you wish to use other datasets with strong sequence property, NextItNet is recommended.
#  <br>Note 3: Time cost of NextItNet Model is significantly shorter than other models because it doesn't need a history expanding of training data.

# %% [markdown]
# ## 3. Online serving
# In this section, we provide a simple example to illustrate how we can use the trained model to serve for production demand.
#
# Suppose we are in a new session. First let's load a previous trained model:

# %%
model_best_trained = SeqModel(hparams, input_creator, seed=RANDOM_SEED)
path_best_trained = os.path.join(hparams.MODEL_DIR, "best_model")
print('loading saved model in {0}'.format(path_best_trained))
model_best_trained.load_model(path_best_trained)
# Out:
# loading saved model in ../../tests/resources/deeprec/slirec/model/best_model
# INFO:tensorflow:Restoring parameters from ../../tests/resources/deeprec/slirec/model/best_model

# %% [markdown]
# Let's see if we load the model correctly. The testing metrics should be close to the numbers we have in the training stage.

# %%
model_best_trained.run_eval(test_file, num_ngs=test_num_ngs)
# Out:
# {'auc': 0.7099,
#  'logloss': 0.6063,
#  'mean_mrr': 0.4902,
#  'ndcg@2': 0.4025,
#  'ndcg@4': 0.5056,
#  'ndcg@6': 0.5555,
#  'group_auc': 0.709}

# %% [markdown]
# And we make predictions using this model. In the next step, we will make predictions using a serving model. Then we can check if the two result files are consistent.

# %%
model_best_trained.predict(test_file, output_file)

# %% [markdown]
# For online serving, usually we only keep the necessary computation nodes and froze the TF model to ab sinle pb file, so that we can easily compute scores with both Python or Java:

# %%
with model_best_trained.sess as sess:
    graph_def = model_best_trained.graph.as_graph_def()
    output_graph_def = tf.graph_util.convert_variables_to_constants(
        sess,
        graph_def,
        ["pred"]
    )

    outfilepath = os.path.join(hparams.MODEL_DIR, "serving_model.pb")
    with tf.gfile.GFile(outfilepath, 'wb') as f:
        f.write(output_graph_def.SerializeToString())
# Out:
# WARNING:tensorflow:From <ipython-input-16-dd62857b20ba>:6: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /home/v-xdeng/.conda/envs/reco_tf15/lib/python3.6/site-packages/tensorflow_core/python/framework/graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 61 variables.
# INFO:tensorflow:Converted 61 variables to const ops.

# %% [markdown]
# The serving logic is as simple as feeding the feature values to the corresponding input nodes, and fetch the score from the output node.
#
# In our model, input nodes are some placeholders and control variables (such as is_training, layer_keeps). We can get the nodes by their name:

# %%
class LoadFrozedPredModel:
    def __init__(self, graph):
        self.pred = graph.get_tensor_by_name('import/pred:0') 
        self.items = graph.get_tensor_by_name('import/items:0') 
        self.cates = graph.get_tensor_by_name('import/cates:0') 
        self.item_history = graph.get_tensor_by_name('import/item_history:0') 
        self.item_cate_history = graph.get_tensor_by_name('import/item_cate_history:0') 
        self.mask = graph.get_tensor_by_name('import/mask:0')  
        self.time_from_first_action = graph.get_tensor_by_name('import/time_from_first_action:0') 
        self.time_to_now = graph.get_tensor_by_name('import/time_to_now:0') 
        self.layer_keeps = graph.get_tensor_by_name('import/layer_keeps:0') 
        self.is_training = graph.get_tensor_by_name('import/is_training:0')

# %%
def infer_as_serving(model, infile, outfile, hparams, iterator, sess):
    preds = []
    
    for batch_data_input in iterator.load_data_from_file(infile, batch_num_ngs=0):
        if batch_data_input:
            feed_dict = {
                model.layer_keeps:np.ones(3, dtype=np.float32),
                model.is_training:False,
                model.items: batch_data_input[iterator.items],
                model.cates: batch_data_input[iterator.cates],
                model.item_history: batch_data_input[iterator.item_history],
                model.item_cate_history: batch_data_input[iterator.item_cate_history],
                model.mask: batch_data_input[iterator.mask],
                model.time_from_first_action: batch_data_input[iterator.time_from_first_action],
                model.time_to_now: batch_data_input[iterator.time_to_now]
            }
            step_pred = sess.run(model.pred, feed_dict=feed_dict)
            preds.extend(np.reshape(step_pred, -1))
                
    with open(outfile, "w") as wt:
        for line in preds:
            wt.write('{0}\n'.format(line))

# %% [markdown]
# Here is the main pipeline for inferring in an online serving manner. You can compare the 'output_serving.txt' with 'output.txt' to see if the results are consistent.

# %%
G = tf.Graph()
with tf.gfile.GFile(
        os.path.join(hparams.MODEL_DIR, "serving_model.pb"),
        'rb'
) as f, G.as_default():
    graph_def_optimized = tf.GraphDef()
    graph_def_optimized.ParseFromString(f.read())
    print('graph_def_optimized = ' + str(graph_def_optimized))


with tf.Session(graph=G) as sess:
    tf.import_graph_def(graph_def_optimized)

    model = LoadFrozedPredModel(sess.graph)
    
    serving_output_file = os.path.join(data_path, r'output_serving.txt')  
    iterator = input_creator(hparams, tf.Graph())
    infer_as_serving(model, test_file, serving_output_file, hparams, iterator, sess)
# Out:
# graph_def_optimized = node {
#   name: "items"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# node {
#   name: "cates"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: -1
#         }
#       }
#     }
#   }
# }
# node {
#   name: "item_history"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: -1
#         }
#         dim {
#           size: 50
#         }
#       }
#     }
#   }
# }
# node {
#   name: "item_cate_history"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: -1
#         }
#         dim {
#           size: 50
#         }
#       }
#     }
#   }
# }
# node {
#   name: "mask"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: -1
#         }
#         dim {
#           size: 50
#         }
#       }
#     }
#   }
# }
# node {
#   name: "time_from_first_action"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: -1
#         }
#         dim {
#           size: 50
#         }
#       }
#     }
#   }
# }
# node {
#   name: "time_to_now"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: -1
#         }
#         dim {
#           size: 50
#         }
#       }
#     }
#   }
# }
# node {
#   name: "layer_keeps"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         unknown_rank: true
#       }
#     }
#   }
# }
# node {
#   name: "is_training"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_BOOL
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "sequential/embedding/item_embedding"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 467
#           }
#           dim {
#             size: 32
#           }
#         }
#         tensor_content: "\243vU\274/\t\357:vG\305\273\221=\234<\321\225\202\274\033\276\342;L\300\\\274\013\272Y;b\345\033<\001\376\370\273\200\261b;\342X\3409hT\325<\236\261V;v\232\252\274\023\324\"<\016\210\200\272c6\242<\017K\024\274\262\300\241\274\200@L\274j\360Y\274t\247\n\274\320\253\302\273\202\001\260\272\000b7<\333\322\304\2740\036\220\272Oh3<\202\265-\273\251\357h<\377uG<\272`\263\274=\301\322<\306V7\273\315]2=e\223\200\274\342\241$<\024x\237\273w[]\274\225\257\256<\260\203\342:c\266\256<\\|\246\273\000-\235;\2700\005<\230\0349\274\327au\274\260\321\330\274\373\271\016<$\314\245\273G\025\036\274\306w\303<b\261R<\352\010\356\274?\276\222<\225\326\026<\331\263v\274h\375/\275\'=f:\254CH\274\377_4\274\307\375\224\274OWm\274\2034/\275ze><\326\277D:\356\327+=\363\226\"\273\025cx<\001\343\235\271\203\301\327\271\2361\r=\031\003\236;\360)M=i\000\n\275\255\275\324<h\t\026=k\204\321\274\236m\355:\213f\023\274\032|:<\250Ez\274\273\247\211\274N\366\262;E\346\337\273\374)\374\2738\272\213;\334{\236\274\265\220\377\274\235z\361\273\311\020\222\273+O\262\274\007\344\301\273I\271\231\274H5-\275@\261\016\275\377:\276<\226\255\035;\177G\"=\224\306S\274\310\362\'<\256r\200<F\235\010<q\354\353<\016\t\236;\207\007\243<\312\024:\275vU\277;d\005I<5\016(\274\245\345v\274\336\325\025\275\000O\253\266OV0<#U\262\274\211\034\265<\272z\207:\305\365\256\273\332{)<R\300\317\274\031\357\214\274uH\240\273\236]A;\210Z\030\275\225,O\274s\2411\274-+\213\274.0Y:\322n\022=\3355\257\274\256J\004=\305\355&<3\351\236:\212\201\216\273\225<)\274\022\340\344;\030\271\336\272\244\262\262<\0221\322\274F\035\352;\253nW;\320\246\010\2745\2543\273\363\322\313\274\0069\305<\2167\321<\016L\237\274\354\344\306;\211\345\356;I\270\233\274\240@\262<R\351\244:d\334\375\273\233\313\222\274g8$\274\361\'\364\273K\257\311\274\332\202\300\274t\246\311\274\325\203\370:\242ZF\275\346\031\320<\025\023\216\274\331\263?\275(\236l<\014l\321:w\032\210\2757M\t\274&vS\275\226a=\275 \230u=\246\344q\274\220kB<\320\254\233\274\355\324\225\275\262\361M=9U\020\275]\213\233\274\362\335a\275\372\025=\275\351P\236\275\365Z\245<\207\241\036\275\2128z\274n\371Z\275x\256\321\273\014\210\214\273\\j\223=o\232\224<\232\016\005=\351\272\351<\'R\r\272[U\321<U\331\252\274V\000\n=\314\022\335\273\316\237\223\270\343,m\274\026\335\003;\200`\220<\341~P;\376f\201<\030\325\326\274\352\207\001=\353\013Y;\372\216\343\273\360h\243\273\017\021\026\2758\240\027<\233\364\260<\363O-;`\005\224<\261\2404\273=\330y\274\252,\270<\256\276I<\224p\224\274\233\331Y\275\000\010\010\273\355|\004\275\347\277|\273\250\003X\273\352\214\234\274\022\246\016\275\237\306\250<\272\034W\274U\033i=\"\255\245\274d\240\274<\t\"\335\273\307\374\203\274/F\324<\302\343\224\273\245\024\257<\325F.\275\203\373\347<#\214{<\363\267\347\274\344\205\203\274\271\312\247\273\322\243\204\272R6,\275/>\000\275\034\243\205<\207X\235;P\303\360\272\270\314o;t\303\002\275\244\316\360\274r\037.\273l\263\231\272\344\230\\<\330^\276\273>S\306<\267wY\275\024D\276\273>N\345<T\362\013\275\235:\212<\326/H\273\235B\217:N|\230: \206N<\223\261\245<\220\200\021=\340\034\246;\367\377\336\274-@\'<dt\206\274\035\360\324\271\'\203\014\274\276g\272\274\231\305\336<\363\217\305;\236)\267\273\335\203\254<v\243\177;\254\366\373\273\212S\254<y8P<0<\230<*}\304\274wno\273\3410\225\274\255R\214\274sE\'\272\325\343\177\274\037\0328=\211G(\274\036\304\265\273\225\014n\275\010>\n=\021k\205\275\020\031\275\273\374w\367<H\275\004\275d|\316\274\220\367\363\274D\327>=\361 \031\275\206\nB\275\233\333N=P\345\303<\357\000\223<Lr\330<\350\366\022=\363R1=d\245\031\273)\313R=\233\233Z=\260\322\343<5\021M=z\023*=\236y\207\275M\014%\274\312\300\220\273\225\243_\275z\327\353\274\326\246\237<\261\261\220\274\225\016\234<u\353e<\331\351H=\340\337k\274\254g\251;\354\'\215\274\253:?\273\003\211\000=\244n\362;\344\241!=\244YK\275\362\3117;(\0341\273Db\032\274\221\267N\274g\257\356\274\313\347\261<\315\3405\273}\222-\274q\354\235<\177F\"\273u\\r\274\276\006\324<\010\364P\274g\"\325\274\340\003A\27 ...
#       }
#     }
#   }
# }
# node {
#   name: "sequential/embedding/item_embedding/read"
#   op: "Identity"
#   input: "sequential/embedding/item_embedding"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/embedding/item_embedding"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/embedding/cate_embedding"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 9
#           }
#           dim {
#             size: 8
#           }
#         }
#         tensor_content: "\010\217%\274\212\356\377\273\216)O\274\334]|\272\354>\263\2739\306\322;\305\254*\274\327\313\346:\216O\002\275\264\227\324\274:\367\r\275\370\371\235\274\310\333\372\273\222T\023=-N\325\274\370\301\322\273G\0336\2748\275j\274\323\317\332\274N\270\206\274t\253K\274\365\016\225<H\221J\272:=\224\273\221-\322\274%\371Q\274\000\217\214<\341\177\013\274\356\254\230<\2168\313\271\222\222\312\274\320\003\2747\261&\363\274\256[\222\274\241:\245;\274\264\306\274\322a\002=\311;\211<\3029\353\274\270W\035<\262\2476\274\002\313q\274\314\242\211<\020\313\3109\010A\326\274\016\365L\274\nX\226<\351k2<&o}<\004j\276\271:G\340;\364Q\\\2742\027P=}\254\267\273\237\272\266\272\227\tG;\"\362\275\274\314w\317\274m\027\245\274rm\303\274i\215\023=\373\013+<\244\036#\2757IP\274\310Z\233\270\001\277K<\333\357\033=\221\227\270\274\036\213\022<B\253\354\273\313\326\r=\372]M;"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/embedding/cate_embedding/read"
#   op: "Identity"
#   input: "sequential/embedding/cate_embedding"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/embedding/cate_embedding"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/embedding_lookup_1/axis"
#   op: "Const"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/embedding/item_embedding"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/embedding_lookup_1"
#   op: "GatherV2"
#   input: "sequential/embedding/item_embedding/read"
#   input: "items"
#   input: "sequential/embedding_lookup_1/axis"
#   attr {
#     key: "Taxis"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/embedding/item_embedding"
#       }
#     }
#   }
#   attr {
#     key: "batch_dims"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/embedding_lookup_1/Identity"
#   op: "Identity"
#   input: "sequential/embedding_lookup_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/embedding_lookup_2/axis"
#   op: "Const"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/embedding/item_embedding"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/embedding_lookup_2"
#   op: "GatherV2"
#   input: "sequential/embedding/item_embedding/read"
#   input: "item_history"
#   input: "sequential/embedding_lookup_2/axis"
#   attr {
#     key: "Taxis"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/embedding/item_embedding"
#       }
#     }
#   }
#   attr {
#     key: "batch_dims"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/embedding_lookup_2/Identity"
#   op: "Identity"
#   input: "sequential/embedding_lookup_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/embedding_lookup_3/axis"
#   op: "Const"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/embedding/cate_embedding"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/embedding_lookup_3"
#   op: "GatherV2"
#   input: "sequential/embedding/cate_embedding/read"
#   input: "cates"
#   input: "sequential/embedding_lookup_3/axis"
#   attr {
#     key: "Taxis"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/embedding/cate_embedding"
#       }
#     }
#   }
#   attr {
#     key: "batch_dims"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/embedding_lookup_3/Identity"
#   op: "Identity"
#   input: "sequential/embedding_lookup_3"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/embedding_lookup_4/axis"
#   op: "Const"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/embedding/cate_embedding"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/embedding_lookup_4"
#   op: "GatherV2"
#   input: "sequential/embedding/cate_embedding/read"
#   input: "item_cate_history"
#   input: "sequential/embedding_lookup_4/axis"
#   attr {
#     key: "Taxis"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/embedding/cate_embedding"
#       }
#     }
#   }
#   attr {
#     key: "batch_dims"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/embedding_lookup_4/Identity"
#   op: "Identity"
#   input: "sequential/embedding_lookup_4"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/concat_2/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: -1
#       }
#     }
#   }
# }
# node {
#   name: "sequential/concat_2"
#   op: "ConcatV2"
#   input: "sequential/embedding_lookup_1/Identity"
#   input: "sequential/embedding_lookup_3/Identity"
#   input: "sequential/concat_2/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/concat/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/concat"
#   op: "ConcatV2"
#   input: "sequential/embedding_lookup_2/Identity"
#   input: "sequential/embedding_lookup_4/Identity"
#   input: "sequential/sli_rec/concat/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/Sum/reduction_indices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/Sum"
#   op: "Sum"
#   input: "mask"
#   input: "sequential/sli_rec/Sum/reduction_indices"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/attention_mat"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 40
#           }
#           dim {
#             size: 40
#           }
#         }
#         tensor_content: "\214\177\250\275\350 \251\275\262\215\300\275\327\002\222\275\024\177\274\275gn\212=\200\003\373\275u\306\263=\245\306\300=\232\304\263\275K\207\220\2751\371\334=\007\t\272=\313\337\231\275\272\346\302\275Pg\305=V\232\367\275\270o\264=\032j\246=\357\010\252\275\225\275\235=\266\020\375\275\353\201\233=\201\374\304=\025g\260\275\371\240\303=N?\307\275<\207\320=-i\275=\241L\276=\014L\252=\323A\260=\315\232\266\275\372T\260=\374\342\256=\360%\344\275\210\253\274=7\270\253\275M\262\300=]\021\300\275\035\031\301=\201\270\275=\323\022\331=k\364\360=D\232\260=\305P\320\275\031\222\362=\026\001\272\275\262\241\312\275\n]\314=\333v\332=\361a\337\275\214\032\235\275*\315\336=[l\271=\212\237\313\275M\326\337=\\\305\300\275\321Q\335\275\025\026\360=\213+\315\275\313\270\303=C\351\342\275#\237\303\275\216^\314=\254>\262\275\204\365\312=4\020\301\275\207$\272\275\rC\247\275\266\223\226\275!\265\306\275\361C\335=IR\262\275\314I\264\275\376\376\337=\273\277\324\275\357\212\324=\033\224\322\275h\331\312=\254\231P=\364\220X=\233\346\355<\"h%=\251\377n=\tY&\275\325T`=c\2457\275\332\341\320\274\260\237\340<p\036%=\317\331\035\275T\2228\275(\312\016=G\3720=\327\177Q\275PZc=\3077\020\275q\034\002\275\261\240A=\264Zj\275\016#6=\216\372\355\274\021^$\275\307{\003=7\345\t\275e\333\313<:\3544\275@BJ\275\225\t?\275p\022\356\274\355cw\275;\253\010=d\024J\275\nj\346\274,\216a=\252\307\005\275y\231,=l\253\r\275l\355.=\035\225\207=\227\233\241=\177]\236=\237\255]=\n\226\276=\227\324h\275\265\243\355=+\347\245\275W\344\260\275L\006\255=dRo=\260\002\273\275\246N\210\275BA\256=`)\312=\332#\266\275V\350\006>\352G\233\275\241o\230\275\262l\234=\317\253\213\275EB\370=\236e\273\275\207v\332\275\221\246\261=\032y\236\275\307\242\345=\222\010\336\275!\210\235\275\001\226\312\275.\221\242\275\341,\276\275\210\277\275=&h\262\275\220-\257\2754\341\350=\031J\274\275\347\317\224=\024\306\234\275\034T\304=\271\034\344\275\252&\356\275\246:\324\275\356\201\236\275rW\356\275\236\302\246=\267#\003\276\213!\306=\206\276\344=xg\336\275\357\206\313\275\007\314\376=p\271\237=\000\207\256\275\203\211\363\275\212\222\254=\247\232\034\276\214\206\274=\341G\334=\006C\301\275\275\273\264=\010\235\025\2767\240\257=\244\305\376=\r\253\364\275\227\216\257=\340Z\276\275\024\\\362=B(\275=\364\342\320=d\266\302=1\326\330=p\202\267\275)\277\273=\305\316\254=\270\271\004\276\t\207\246=\306\271\305\275\221\013\321=\242\360\273\275\272\363\201=\275b\230=\031\330\241=\345t\222=\273\342\263=\263if\275\342\245\355=\311_\244\275-C\325\275\207y\275=h\267\275=\277t\301\275\305g\241\275K\233\225=\321\371\235=\t\031\245\275#\250\020>\027\205\225\275\342]\235\275)\242\221=\273\007\305\275\276\215\373=\205T\263\275\005\226\354\275\007\367\303=\266\364\211\275\017p\327=}\373\250\275E\205\260\275R\252\270\275\201\322n\275\244*\312\275\240\270\267=\257\030\254\275\246\261\243\275\023x\330=\"\345\213\275{\017\204=\202,\256\275h[\272=^wL:\005\220K<\352z\002\272N2<;\210\220\035\274\033r\031<\270].<\321\377\304\273\005\237K\274\326d\314;B\234\371;\006N\216; \247c\273\345\354\n<\342\324\017<\276+\352\273\361\201\t<F(\010\273\240\224\200\273|\361\217;Fof\274}\363 <\356\3162\274Z\302\205;\304Qn<\264\327%<k{G\273\254\362A\274\352._\274\244d\264;\357\204@\274zv\264\273\202$\244;\344P*;\007\253[\2744f\010\274\326\325\345\273\231\233\243\272{u\336;\314)2;^\260\260\275J\372\263\275r\212\301\275\353\322\253\275fe\330\275\023\273\260=\223\301\341\275%\336\301=\265\354\344=\002\234\260\275\005\201\305\275\256E\254=\212m\314=\3375\306\275xs\272\275U7\267=\000!\006\276x\231\243=<\327\303=\265\313\262\275\212\202\301=\253v\371\275Ta\311=\240C\341=q\334\314\275\222\211\256=\206a\320\275\205\220\312=\256\201\312=%N\341=\213\254\277=\177$\342=\024\233\272\275\r\216\335=$\314\266=\223L\373\275$8\227=1F\334\275\204\023\277=\377\014\276\275\005A\336=\007\210\325=\245t\010>\325\033\314=\336\206\332=\025\236\320\275\241Z\021>\276\003\353\275/\344\314\275\270\223\353=\330\363\311=\005\004\t\276\013\317\340\2 ...
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/attention_mat/read"
#   op: "Identity"
#   input: "sequential/sli_rec/long_term_asvd/attention_mat"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/sli_rec/long_term_asvd/attention_mat"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/axes"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/free"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\000\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/Shape"
#   op: "Shape"
#   input: "sequential/sli_rec/concat"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/GatherV2/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/GatherV2"
#   op: "GatherV2"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/Shape"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/free"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/GatherV2/axis"
#   attr {
#     key: "Taxis"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "batch_dims"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/GatherV2_1/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/GatherV2_1"
#   op: "GatherV2"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/Shape"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/axes"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/GatherV2_1/axis"
#   attr {
#     key: "Taxis"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "batch_dims"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/Prod"
#   op: "Prod"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/GatherV2"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/Const_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/Prod_1"
#   op: "Prod"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/GatherV2_1"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/concat/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/concat"
#   op: "ConcatV2"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/free"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/axes"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/concat/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/stack"
#   op: "Pack"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/Prod"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/Prod_1"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/transpose"
#   op: "Transpose"
#   input: "sequential/sli_rec/concat"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/concat"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tperm"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/Reshape"
#   op: "Reshape"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/transpose"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/stack"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/transpose_1/perm"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\000\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/transpose_1"
#   op: "Transpose"
#   input: "sequential/sli_rec/long_term_asvd/attention_mat/read"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/transpose_1/perm"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tperm"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/Reshape_1/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "(\000\000\000(\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/Reshape_1"
#   op: "Reshape"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/transpose_1"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/Reshape_1/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/MatMul"
#   op: "MatMul"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/Reshape"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/Reshape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/Const_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 40
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/concat_1/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot/concat_1"
#   op: "ConcatV2"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/GatherV2"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/Const_2"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/concat_1/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Tensordot"
#   op: "Reshape"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/MatMul"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot/concat_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/query"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 40
#           }
#         }
#         tensor_content: "6\204\030\276\236\346\n\276\242H)\276>\027\024\276\2769\033\276D\330\007>m\353/\276\374\274\022>,\350%>\354\243\017\276\252O\023\276\274c(>\357\365\022>\372\304\023\276R\324#\276\231\357\020>\203N>\276\246\007\013>\275\232\036>\320\334\030\276Zc\024>\221\3169\276\341\312\036>1\352*>\035\022(\276r\223\022>\3711\036\276{\"\">\222t\032>\356b\004>\005\344\010>Fl#>>C\030\276(\344\013>\212\277\010>\323P!\276w,\022>\026#\037\276\305e\036>K\205\034\276"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/query/read"
#   op: "Identity"
#   input: "sequential/sli_rec/long_term_asvd/query"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/sli_rec/long_term_asvd/query"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/axes"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/free"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\000\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/Shape"
#   op: "Shape"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/GatherV2/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/GatherV2"
#   op: "GatherV2"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/Shape"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/free"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/GatherV2/axis"
#   attr {
#     key: "Taxis"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "batch_dims"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/GatherV2_1/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/GatherV2_1"
#   op: "GatherV2"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/Shape"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/axes"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/GatherV2_1/axis"
#   attr {
#     key: "Taxis"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "batch_dims"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/Prod"
#   op: "Prod"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/GatherV2"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/Const_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/Prod_1"
#   op: "Prod"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/GatherV2_1"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/concat/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/concat"
#   op: "ConcatV2"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/free"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/axes"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/concat/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/stack"
#   op: "Pack"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/Prod"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/Prod_1"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/transpose"
#   op: "Transpose"
#   input: "sequential/sli_rec/long_term_asvd/Tensordot"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/concat"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tperm"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/Reshape"
#   op: "Reshape"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/transpose"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/stack"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/transpose_1/perm"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/transpose_1"
#   op: "Transpose"
#   input: "sequential/sli_rec/long_term_asvd/query/read"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/transpose_1/perm"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tperm"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/Reshape_1/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "(\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/Reshape_1"
#   op: "Reshape"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/transpose_1"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/Reshape_1/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/MatMul"
#   op: "MatMul"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/Reshape"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/Reshape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/Const_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#           }
#         }
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/concat_1/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits/concat_1"
#   op: "ConcatV2"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/GatherV2"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/Const_2"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/concat_1/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_logits"
#   op: "Reshape"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/MatMul"
#   input: "sequential/sli_rec/long_term_asvd/att_logits/concat_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/att_weights"
#   op: "Softmax"
#   input: "sequential/sli_rec/long_term_asvd/att_logits"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/ExpandDims/dim"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: -1
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/ExpandDims"
#   op: "ExpandDims"
#   input: "sequential/sli_rec/long_term_asvd/att_weights"
#   input: "sequential/sli_rec/long_term_asvd/ExpandDims/dim"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tdim"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/mul"
#   op: "Mul"
#   input: "sequential/sli_rec/concat"
#   input: "sequential/sli_rec/long_term_asvd/ExpandDims"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Sum/reduction_indices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/long_term_asvd/Sum"
#   op: "Sum"
#   input: "sequential/sli_rec/long_term_asvd/mul"
#   input: "sequential/sli_rec/long_term_asvd/Sum/reduction_indices"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/ExpandDims/dim"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: -1
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/ExpandDims"
#   op: "ExpandDims"
#   input: "time_from_first_action"
#   input: "sequential/sli_rec/ExpandDims/dim"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tdim"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/concat_1/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: -1
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/concat_1"
#   op: "ConcatV2"
#   input: "sequential/embedding_lookup_2/Identity"
#   input: "sequential/sli_rec/ExpandDims"
#   input: "sequential/sli_rec/concat_1/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/ExpandDims_1/dim"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: -1
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/ExpandDims_1"
#   op: "ExpandDims"
#   input: "time_to_now"
#   input: "sequential/sli_rec/ExpandDims_1/dim"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tdim"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/concat_2/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: -1
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/concat_2"
#   op: "ConcatV2"
#   input: "sequential/sli_rec/concat_1"
#   input: "sequential/sli_rec/ExpandDims_1"
#   input: "sequential/sli_rec/concat_2/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/Rank"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 3
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/range/start"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/range/delta"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/range"
#   op: "Range"
#   input: "sequential/sli_rec/rnn/time4lstm/range/start"
#   input: "sequential/sli_rec/rnn/time4lstm/Rank"
#   input: "sequential/sli_rec/rnn/time4lstm/range/delta"
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/concat/values_0"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\001\000\000\000\000\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/concat/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/concat"
#   op: "ConcatV2"
#   input: "sequential/sli_rec/rnn/time4lstm/concat/values_0"
#   input: "sequential/sli_rec/rnn/time4lstm/range"
#   input: "sequential/sli_rec/rnn/time4lstm/concat/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/transpose"
#   op: "Transpose"
#   input: "sequential/sli_rec/concat_2"
#   input: "sequential/sli_rec/rnn/time4lstm/concat"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tperm"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/sequence_length"
#   op: "Identity"
#   input: "sequential/sli_rec/Sum"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/Shape"
#   op: "Shape"
#   input: "sequential/sli_rec/rnn/time4lstm/transpose"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/strided_slice/stack"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/strided_slice/stack_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 2
#       }
#     }
#   }
# }
# node {
#   name: "sequential/sli_rec/rnn/time4lstm/strided_slice/stack_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
# ...
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/random_uniform/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/random_uniform/RandomUniform"
#   op: "RandomUniform"
#   input: "sequential/logit_fcn/nn_part/dropout_1/Shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/random_uniform/sub"
#   op: "Sub"
#   input: "sequential/logit_fcn/nn_part/dropout_1/random_uniform/max"
#   input: "sequential/logit_fcn/nn_part/dropout_1/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/random_uniform/mul"
#   op: "Mul"
#   input: "sequential/logit_fcn/nn_part/dropout_1/random_uniform/RandomUniform"
#   input: "sequential/logit_fcn/nn_part/dropout_1/random_uniform/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/random_uniform"
#   op: "Add"
#   input: "sequential/logit_fcn/nn_part/dropout_1/random_uniform/mul"
#   input: "sequential/logit_fcn/nn_part/dropout_1/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/sub/x"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/sub"
#   op: "Sub"
#   input: "sequential/logit_fcn/nn_part/dropout_1/sub/x"
#   input: "sequential/logit_fcn/nn_part/sub_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/truediv/x"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 1.0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/truediv"
#   op: "RealDiv"
#   input: "sequential/logit_fcn/nn_part/dropout_1/truediv/x"
#   input: "sequential/logit_fcn/nn_part/dropout_1/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/GreaterEqual"
#   op: "GreaterEqual"
#   input: "sequential/logit_fcn/nn_part/dropout_1/random_uniform"
#   input: "sequential/logit_fcn/nn_part/sub_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/mul"
#   op: "Mul"
#   input: "sequential/logit_fcn/nn_part/batch_normalization_1/batchnorm/add_1"
#   input: "sequential/logit_fcn/nn_part/dropout_1/truediv"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/Cast"
#   op: "Cast"
#   input: "sequential/logit_fcn/nn_part/dropout_1/GreaterEqual"
#   attr {
#     key: "DstT"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "SrcT"
#     value {
#       type: DT_BOOL
#     }
#   }
#   attr {
#     key: "Truncate"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/dropout_1/mul_1"
#   op: "Mul"
#   input: "sequential/logit_fcn/nn_part/dropout_1/mul"
#   input: "sequential/logit_fcn/nn_part/dropout_1/Cast"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Relu_1"
#   op: "Relu"
#   input: "sequential/logit_fcn/nn_part/dropout_1/mul_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/w_nn_output"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 64
#           }
#           dim {
#             size: 1
#           }
#         }
#         tensor_content: "$1e\275xd\220\275~\340\205\275~\273I=3v_\275\364\360@=s\233L\275\254\\.=\353do=\352IO=ztl=\203&v=\355:U=\342\376:=\355O\262\275m\250K=\030\245H=5\'U=\341\2313\275\365aM=\265\277D=\365\n{\275\376|l=Z)<=k\236\210\275\205\256{=\347\257\215\275\3536L=\t\233\'=x\023L=L4P=\234\360U\275,\013K=c*l\275\301\232\223\2751MH=\232cr\275\331t5\275\\\3227=\305\014o\275\t\311t\275\364\364\202\275s\340\205\275e_@=\tLn\275\363\031\220\275G$Z=\266K*=c\336\207\275(\036\246\275\351\210]\275\234\035e\275\336\252^=9\316\224\275\314\230\212\275\320\247A=\265\257r=+&T\275\\R<=u\211_=Z\320i\275\266\366\200\275o\260\207\275\371 M="
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/w_nn_output/read"
#   op: "Identity"
#   input: "sequential/logit_fcn/nn_part/w_nn_output"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/logit_fcn/nn_part/w_nn_output"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/b_nn_output"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         float_val: 0.018102169036865234
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/b_nn_output/read"
#   op: "Identity"
#   input: "sequential/logit_fcn/nn_part/b_nn_output"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@sequential/logit_fcn/nn_part/b_nn_output"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/axes"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/free"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/Shape"
#   op: "Shape"
#   input: "sequential/logit_fcn/nn_part/Relu_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "out_type"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/GatherV2/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/GatherV2"
#   op: "GatherV2"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/Shape"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/free"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/GatherV2/axis"
#   attr {
#     key: "Taxis"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "batch_dims"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/GatherV2_1/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/GatherV2_1"
#   op: "GatherV2"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/Shape"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/axes"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/GatherV2_1/axis"
#   attr {
#     key: "Taxis"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tindices"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tparams"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "batch_dims"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/Prod"
#   op: "Prod"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/GatherV2"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/Const_1"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/Prod_1"
#   op: "Prod"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/GatherV2_1"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/Const_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "keep_dims"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/concat/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/concat"
#   op: "ConcatV2"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/free"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/axes"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/concat/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/stack"
#   op: "Pack"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/Prod"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/Prod_1"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/transpose"
#   op: "Transpose"
#   input: "sequential/logit_fcn/nn_part/Relu_1"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/concat"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tperm"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/Reshape"
#   op: "Reshape"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/transpose"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/stack"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/transpose_1/perm"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "\000\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/transpose_1"
#   op: "Transpose"
#   input: "sequential/logit_fcn/nn_part/w_nn_output/read"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/transpose_1/perm"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tperm"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/Reshape_1/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 2
#           }
#         }
#         tensor_content: "@\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/Reshape_1"
#   op: "Reshape"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/transpose_1"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/Reshape_1/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/MatMul"
#   op: "MatMul"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/Reshape"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/Reshape_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/Const_2"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         int_val: 1
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/concat_1/axis"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#         }
#         int_val: 0
#       }
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2/concat_1"
#   op: "ConcatV2"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/GatherV2"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/Const_2"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/concat_1/axis"
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Tidx"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/Tensordot_2"
#   op: "Reshape"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/MatMul"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2/concat_1"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "sequential/logit_fcn/nn_part/add_2"
#   op: "AddV2"
#   input: "sequential/logit_fcn/nn_part/Tensordot_2"
#   input: "sequential/logit_fcn/nn_part/b_nn_output/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "Sigmoid"
#   op: "Sigmoid"
#   input: "sequential/logit_fcn/nn_part/add_2"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "pred"
#   op: "Identity"
#   input: "Sigmoid"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# library {
# }

# %% [markdown]
# ## Reference
# \[1\] Zeping Yu, Jianxun Lian, Ahmad Mahmoody, Gongshen Liu, Xing Xie. Adaptive User Modeling with Long and Short-Term Preferences for Personailzed Recommendation. In Proceedings of the 28th International Joint Conferences on Artificial Intelligence, IJCAI’19, Pages 4213-4219. AAAI Press, 2019.
#
# \[2\] Balázs Hidasi, Alexandros Karatzoglou, Linas Baltrunas, Domonkos Tikk. Session-based Recommendations with Recurrent Neural Networks. ICLR (Poster) 2016
#
# \[3\] Tang, Jiaxi, and Ke Wang. Personalized top-n sequential recommendation via convolutional sequence embedding. Proceedings of the Eleventh ACM International Conference on Web Search and Data Mining. ACM, 2018.
#
# \[4\] Yuan, F., Karatzoglou, A., Arapakis, I., Jose, J. M., & He, X. A Simple Convolutional Generative Network for Next Item Recommendation. WSDM, 2019
